# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data.db')
table1 = "test_table"
table2 = "entry_cnt"
cmd = f'''
SELECT "{table1}".run_id,monitor_tag,workers,tasks_per_trial,trial,"{table1}".app_name,record_num FROM "{table1}"
JOIN "{table2}"
ON '{table1}'.run_id = '{table2}'.run_id
'''
tasks = pd.read_sql_query(cmd, conn)
tasks
# Out:
#                                    run_id monitor_tag  workers  \
# 0    bc20c23a-e273-4bbe-aca2-5483278957bd        htex        1
# 1    301f9c79-b4bb-4afc-855e-8609c0fef61e        htex        1
# 2    255d44e9-b0ad-4bbc-bf55-9b1df715b4e7        htex        1
# 3    88ea3915-8e22-43ed-9107-e69553b64c60    diaspora        1
# 4    ccf70684-c335-4f3d-b803-d381712d4af2    diaspora        1
# ..                                    ...         ...      ...
# 475  189c4131-3942-41e2-90ee-a055c8df0649        htex      128
# 476  146d2aeb-3b25-452c-8f84-2bae52993ede        htex      128
# 477  ba127e43-4f5a-4dfc-a9af-a2f91eb44f88    diaspora      128
# 478  b47015c9-d65b-45c8-a4d0-d28820d55ccd    diaspora      128
# 479  9ed4793c-ff9e-44a4-91cc-940bccc65085    diaspora      128
#
#      tasks_per_trial  trial    app_name  record_num
# 0                128      1        noop           2
# 1                128      1   sleep10ms           2
# 2                128      1  sleep100ms           3
# 3                128      1        noop           2
# 4                128      1   sleep10ms           2
# ..               ...    ...         ...         ...
# 475              128     10   sleep10ms          65
# 476              128     10  sleep100ms          63
# 477              128     10        noop          55
# 478              128     10   sleep10ms          58
# 479              128     10  sleep100ms          64
#
# [480 rows x 7 columns]
