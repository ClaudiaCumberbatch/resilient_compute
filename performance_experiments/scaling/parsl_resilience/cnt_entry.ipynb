# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('data.db')
table1 = "trail3-2024-03-23_02-02-06"
table2 = "entry_cnt"
cmd = f'''
SELECT "{table1}".run_id,monitor_tag,workers,tasks_per_trial,trial,"{table1}".app_name,record_num FROM "{table1}"
JOIN "{table2}"
ON '{table1}'.run_id = '{table2}'.run_id
'''
tasks = pd.read_sql_query(cmd, conn)
tasks
# Out:
#                                   run_id monitor_tag  workers  \
# 0   54a82330-0f44-4e5c-972d-0f88256649d7        htex        8
# 1   a1ecf360-e562-4143-b150-a68c25ca4564        htex        8
# 2   aa077f86-99d0-42e6-8ddf-dc20b2a0fc06        htex        8
# 3   9ebc6c2d-3dd2-411d-911a-73678ebc29b1        htex        8
# 4   bc928098-4c67-412e-8623-d9dab4a8bca2        htex        8
# 5   434fb3db-141a-4ebc-8955-95f3381dfcc9        htex        8
# 6   6f50aeb9-f77f-4bab-8087-f205eed2b303        htex        8
# 7   9721f061-b4e8-4765-9ded-68c0cc83b5f7        htex        8
# 8   64ba8cb9-5971-48bf-9e37-3bfcf4b24458        htex        8
# 9   2aa5d9c7-e055-4e1c-9872-90490f7e5968        htex       64
# 10  a6aba2fb-25ea-4cd0-9c2a-ceff25ad3104        htex       64
# 11  fe600063-a8aa-45cb-b8c7-871f366dcd99        htex       64
# 12  13c1fc93-8b12-4a8c-97d9-11ba7ea722f6        htex       64
# 13  f88982e7-6be8-4dbc-b9f4-721a5e9000b6        htex       64
# 14  a44292f8-ca73-4f7b-b90a-ce1b36345377        htex       64
# 15  29d2d201-3e40-43d4-ae82-d9981eede419        htex       64
# 16  5fec965c-6cde-44ae-a22f-5f7373803ff3        htex       64
# 17  b8ed5b48-e54c-4774-8981-21a1c7c31be8        htex       64
# 18  b9bb9d04-e004-4ebe-8eb7-60ef22bb570e        htex      128
# 19  728a32a0-ef0e-4a2c-8913-be4fe431e696        htex      128
# 20  6c5028dd-434f-4a6f-ba0e-92ae5e3a88b8        htex      128
# 21  b931bd56-41c8-4bac-9b70-6cba267518d9        htex      128
# 22  913aa66b-f2fd-4f60-9711-346f7e8f49a9        htex      128
# 23  33427f79-d085-4cea-9142-f65a19b14044        htex      128
# 24  6f98af6c-e7ea-43ab-93d6-342db6bf2f4b        htex      128
# 25  11b72504-5a91-4e69-a2ca-dad370d516bf        htex      128
# 26  f35d05f1-4c85-48c0-bca8-f0b2341eeae0        htex      128
# 27  926383c5-3dcd-4e3d-9a5a-47909ea828e9        htex      160
# 28  bf880779-3f83-430f-8fff-2d7223850c54        htex      160
# 29  e98c98c8-c154-42ec-a5b2-f874e2b221e1        htex      160
# 30  c3561392-2008-47f7-a88b-949471dc7690        htex      160
# 31  d4416974-ed83-4560-a37a-06066bf4b58d        htex      160
# 32  047928d4-e299-4699-b0a3-68a832036bd0        htex      160
# 33  411811c6-e268-424b-b651-a563590115b7        htex      160
# 34  68135e17-4c0c-4ce2-b615-985def1dad45        htex      160
# 35  72682fe3-f42b-4cf3-8a8c-699217b0b565        htex      160
# 36  4a691fe3-a254-46a7-ad11-1b38d55dc82c    diaspora        8
# 37  d3aca598-5aaa-432a-a46b-cb3185ab35b7    diaspora        8
# 38  67f00a4d-1411-40ba-ac00-b34325b0859c    diaspora        8
# 39  0d2a5268-abe9-40cd-8a90-ab7bb93618cd    diaspora        8
# 40  71ceb77b-242f-4e88-841e-8467b114672d    diaspora        8
# 41  73e5074e-e03e-493f-8af8-f308ddd1b04c    diaspora        8
# 42  41432361-daea-49ca-804b-741279f56c54    diaspora        8
# 43  70724e84-18be-46a1-b4dd-3c8dd34542c5    diaspora        8
# 44  f2be4d7a-c821-4d23-b017-2b6935adb40f    diaspora        8
# 45  809d31a3-7ae6-445e-bc2a-ad8898366a26    diaspora       64
# 46  33b9b475-497b-4141-93dc-5b60f6fe267b    diaspora       64
# 47  08171258-80b1-444b-ab3d-2c47b5924beb    diaspora       64
# 48  89bf0812-6cd5-4c45-b9e9-37bf3f7ec9b7    diaspora       64
# 49  e3a4be9e-93c6-48cc-9b6a-6716332172a1    diaspora       64
# 50  ad3394ba-9238-4837-82f2-b932675d485e    diaspora       64
# 51  be2ee058-156c-41f3-aab0-f5157fb1cd42    diaspora       64
#
#     tasks_per_trial  trial    app_name  record_num
# 0              1000      0        noop        3656
# 1              1000      1        noop        3104
# 2              1000      2        noop        3508
# 3              1000      0   sleep10ms        3352
# 4              1000      1   sleep10ms        3320
# 5              1000      2   sleep10ms        2743
# 6              1000      0  sleep100ms        3041
# 7              1000      1  sleep100ms        3004
# 8              1000      2  sleep100ms        2872
# 9              1000      0        noop        4112
# 10             1000      1        noop        3931
# 11             1000      2        noop        3728
# 12             1000      0   sleep10ms        3524
# 13             1000      1   sleep10ms        3302
# 14             1000      2   sleep10ms      112527
# 15             1000      0  sleep100ms        2865
# 16             1000      1  sleep100ms        1999
# 17             1000      2  sleep100ms        2408
# 18             1000      0        noop        2259
# 19             1000      1        noop        1994
# 20             1000      2        noop        1741
# 21             1000      0   sleep10ms        1513
# 22             1000      1   sleep10ms      114832
# 23             1000      2   sleep10ms         912
# 24             1000      0  sleep100ms         656
# 25             1000      1  sleep100ms         272
# 26             1000      2  sleep100ms      113279
# 27             1000      0        noop      114246
# 28             1000      1        noop      113447
# 29             1000      2        noop      113217
# 30             1000      0   sleep10ms      112146
# 31             1000      1   sleep10ms      112489
# 32             1000      2   sleep10ms      111340
# 33             1000      0  sleep100ms      110495
# 34             1000      1  sleep100ms      110030
# 35             1000      2  sleep100ms      109461
# 36             1000      0        noop        5641
# 37             1000      1        noop       12112
# 38             1000      2        noop        4947
# 39             1000      0   sleep10ms        9064
# 40             1000      1   sleep10ms        4320
# 41             1000      2   sleep10ms        3904
# 42             1000      0  sleep100ms        7952
# 43             1000      1  sleep100ms        7525
# 44             1000      2  sleep100ms        2664
# 45             1000      0        noop       13121
# 46             1000      1        noop       12179
# 47             1000      2        noop       11333
# 48             1000      0   sleep10ms         422
# 49             1000      1   sleep10ms        9323
# 50             1000      0  sleep100ms        6684
# 51             1000      1  sleep100ms        1433
